# %%
import financeMain
# Out:
# <script src="//code.highcharts.com/stock/highstock.js"></script>
# <script src="//code.highcharts.com/highcharts-more.js"></script>
# <script src="//code.highcharts.com/modules/exporting.js"></script>

# %%
pairData = financeMain.Pair()

# %%
# ペアのチャートを表示
#pairData.ShowAll()
#pairData.Show('EURUSD')

# %%
# 通貨ごとの対チャートを表示
#pairData.ShowVersus('USD')
#pairData.ShowVersus('EUR')
#pairData.ShowVersus('JPY')

# %%
pairData.ShowVersusAll()
# Out:
# <div id="chart_idbssizDaI"</div>
# ...

# %%
# Out:
# <div id="chart_idLDfNtUnB"</div>
# ...
